# %%
import json
import os

# Define the Kaggle directory path
kaggle_dir = os.path.expanduser('~/.kaggle')

# Create the .kaggle directory if it doesn't exist
os.makedirs(kaggle_dir, exist_ok=True)

# Define the credentials
kaggle_credentials = {
    "username": "parthvasave",
    "key": "KGAT_a73d22dec23f47fce3b4cc427071868d"
}

# Define the kaggle.json file path
kaggle_json_path = os.path.join(kaggle_dir, 'kaggle.json')

# Write the credentials to kaggle.json
with open(kaggle_json_path, 'w') as f:
    json.dump(kaggle_credentials, f)

# Set permissions for the kaggle.json file (important for security)
os.chmod(kaggle_json_path, 0o600)

print(f"kaggle.json created at {kaggle_json_path}")
# Out:
# kaggle.json created at /root/.kaggle/kaggle.json

# %%
# !git clone https://github.com/Parth-Vasave/Selfie2Image
# Out:
# Cloning into 'Selfie2Image'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14 (delta 1), reused 14 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 11.99 KiB | 6.00 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd Selfie2Image
# Out:
# /content/Selfie2Image

# %%
# !pip install -q gradio opencv-python-headless kaggle

# %%
# !kaggle datasets download -d t04glovern/ugatit-selfie2anime-pretrained -p /tmp/ugatit --unzip
# !mkdir -p checkpoint
# !cp -r /tmp/ugatit/* checkpoint/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/t04glovern/ugatit-selfie2anime-pretrained
# License(s): CC0-1.0
# Downloading ugatit-selfie2anime-pretrained.zip to /tmp/ugatit
#  98% 1.38G/1.40G [00:15<00:00, 154MB/s]
# 100% 1.40G/1.40G [00:19<00:00, 78.5MB/s]

# %%
import os
import tensorflow as tf

print(f"TensorFlow: {tf.__version__}")
print(f"GPU: {tf.config.list_physical_devices('GPU')}")

# Check checkpoint exists
ckpt_dir = 'checkpoint/UGATIT_light_selfie2anime_lsgan_4resblock_6dis_1_1_10_10_1000_sn_smoothing'
if os.path.exists(ckpt_dir):
    print(f"✅ Checkpoint found: {len(os.listdir(ckpt_dir))} files")
else:
    print("❌ Checkpoint not found!")
    # List what we have
    if os.path.exists('checkpoint'):
        for item in os.listdir('checkpoint'):
            print(f"  - {item}")
# Out:
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ❌ Checkpoint not found!
#   - checkpoint
